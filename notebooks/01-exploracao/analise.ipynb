# %% [markdown]
# Sprint 1 (Importação dos dados):

# %%
# Importacao das Bibliotecas:

import pandas as pd
from pathlib import Path
import os

# Importacao dos dados e leitura inicial
raw_path = '../../data/raw/Base Varejo.csv'
df = pd.read_csv(raw_path, sep=';', encoding='utf-8')

#  Mensagem de Confirmação
print(f"{'='*30}")
print(f"LEITURA CONCLUÍDA COM SUCESSO!")
print(f"Dataset: {raw_path.split('/')[-1]}")
print(f"Total de Linhas: {df.shape[0]:,}")
print(f"Total de Colunas: {df.shape[1]}")
print(f"{'='*30}\n")

#  Exibição dos Dados Iniciais
print("--- PRIMEIRAS 5 LINHAS ---")
display(df.head())

# 4. Diagnóstico Técnico Inicial
print("\n--- INFORMAÇÕES TÉCNICAS ---")
df.info()
# Out:
# ...
# LEITURA CONCLUÍDA COM SUCESSO!
# Dataset: Base Varejo.csv
# Total de Linhas: 830,000
# Total de Colunas: 14
# ...
#
# --- PRIMEIRAS 5 LINHAS ---
#          DATA  CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID     PR_CAT  \
# 0  01/02/2019   1000    534         M      4       1      C     67    BEBIDAS
# 1  01/02/2019   1000    534         M      4       1      C     70    BEBIDAS
# 2  01/02/2019   1000    534         M      4       1      C    178    HIGIENE
# 3  01/02/2019   1000    534         M      4       1      C      4  ALIMENTOS
# 4  01/02/2019   1000    534         M      4       1      C    175    LIMPEZA
#
#                 PR_NOME  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0  REFRIGERANTE GUARANA          NaN          NaN          NaN          NaN
# 1   REFRIGERANTE OUTROS          NaN          NaN          NaN          NaN
# 2       LENCO UMEDECIDO          NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# Sprint 2 (Transformação de Strings, Integer e Float e Datetime):

# %%
# Importando funcoes de limpeza da pasta util 
import sys
import os
sys.path.append(os.path.abspath('../../'))
from src.utils.limpeza import transformar_strings, converter_para_numerico, transformar_datetime
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # Importando funcoes de limpeza da pasta util
#       2 import sys
#       3 import os
#       4 sys.path.append(os.path.abspath('../../'))
# ----> 5 from src.utils.limpeza import transformar_strings, converter_para_numerico, transformar_datetime
#
# File c:\Users\Usuario\Desktop\ProjetoVarejo\src\utils\limpeza.py:86
#      83     print(f"Contagem: {int(stats['count'])}")
#      84     print(f"Quartis: Q1={stats['25%']}, Q2={stats['50%']}, Q3={stats['75%']}")
# ---> 86 gerar_relatorio_estatistico(df)
#
# NameError: name 'df' is not defined

# %%
df = df.isnan().sum()
print (df)
# Out:
# 0
